# %% [markdown]
# ### ************ Regression ******************

# %% [markdown]
# #### What is Regression in Supervised Learning?

# %% [markdown]
# Regression is a type of Supervised Machine Learning algorithm
# used to predict continuous numerical values.
#
# Simple Definition
#
# * Regression is a machine learning technique used to predict a numerical value based on input features.

# %% [markdown]
# #### What is a Continuous Value?

# %% [markdown]
# A continuous value is a number that can take any value within a range.
#
# Examples:
#
# * ₹45,250 (Salary)
# * ₹75,50,000 (House Price)
# * 23.5°C (Temperature)
# * 68.2 kg (Weight)
#
# Unlike categories (such as Yes/No or Spam/Not Spam), these values are numerical and continuous.

# %% [markdown]
# Regression Workflow
# * Training Data
# *       │
# *       ▼
# * Regression Algorithm
# *       │
# *       ▼
# * Trained Model
# *       │
# *       ▼
# * Predict Continuous Value

# %% [markdown]
# ### Regression Algorithms

# %% [markdown]
# Regression
#
#       │
#       ├── Linear Regression
#       ├── Polynomial Regression
#       ├── Ridge Regression
#       ├── Lasso Regression
#       ├── Elastic Net Regression
#       ├── Decision Tree Regression
#       ├── Random Forest Regression
#       ├── Support Vector Regression (SVR)
#       ├── K-Nearest Neighbors (KNN) Regression
#       ├── Gradient Boosting Regression
#       ├── XGBoost Regression
#       ├── LightGBM Regression
#       └── CatBoost Regression
