# %% [markdown]
# ### ************* Support Vector Machine *************

# %% [markdown]
# SVM is a margin-based classifier that finds the optimal hyperplane separating data points of different classes with the maximum margin.
#
# * The hyperplane is the decision boundary.
# * The support vectors are the data points closest to the boundary, which directly influence its position.
# * The goal is to maximize the margin (distance between the hyperplane and support vectors), ensuring better generalization.

# %% [markdown]
# #### ✨ Key Idea
# * If data is linearly separable, SVM finds a straight line (in 2D) or hyperplane (in higher dimensions).
# * If data is not linearly separable, SVM uses the kernel trick to project data into a higher-dimensional space where separation is possible.

# %% [markdown]
# * Support Vectors: The critical data points closest to the decision boundary; they define the hyperplane.
# * Linear SVM: Works when data is linearly separable.
# * Non‑linear SVM: Uses kernel trick to project data into higher dimensions where it becomes separable.
# * Common Kernels:
#     * Linear
#     * Polynomial
#     * Radial Basis Function (RBF)
#     * Sigmoid
#
# * Advantages:
#     * Effective in high‑dimensional spaces.
#     * Works well with clear margin of separation.
#     * Robust against overfitting (especially with proper kernel and regularization).
#
# * Disadvantages:
#     * Computationally expensive for very large datasets.
#     * Choice of kernel and parameters is critical.
#     * Less interpretable compared to decision trees.

# %% [markdown]
# #### ⚡ Example
# Imagine you have two types of fruits (apples and oranges) plotted by weight and size.
# * SVM will find the line that best separates apples from oranges.
# * The fruits closest to this line are the support vectors.
# * The line is chosen so that the margin between the two classes is maximized.
