# %% [markdown]
# ### ************** CROSS VALIDATION ****************

# %% [markdown]
# Cross Validation is a model evaluation technique in which the dataset is split into multiple subsets, and the model is trained and tested multiple times using different combinations of these subsets to obtain a reliable estimate of performance.

# %% [markdown]
# Consider a dataset of 1000 records.
#
# * Single Train-Test Split
#     * Training Data = 80%
#     * Testing Data = 20%
#
# Suppose accuracy = 95%.
# * But this accuracy depends on the particular split.
# * Another split might give:
#     * Accuracy = 88%

# %% [markdown]
# #### K-Fold Cross Validation
#
# * Suppose we have:
# * 100 samples
#
# Split into 5 equal parts:
#
# * Fold1 Fold2 Fold3 Fold4 Fold5
# * 20 20 20 20 20
#
# Iteration 1
# * Train → Fold2 Fold3 Fold4 Fold5
# * Test → Fold1
#
# Iteration 2
# * Train → Fold1 Fold3 Fold4 Fold5
# * Test → Fold2
#
# Iteration 3
# * Train → Fold1 Fold2 Fold4 Fold5
# * Test → Fold3
#
# Iteration 4
# * Train → Fold1 Fold2 Fold3 Fold5
# * Test → Fold4
#
# Iteration 5
# * Train → Fold1 Fold2 Fold3 Fold4
# * Test → Fold5
